# %% [markdown]
# ## CLEAN HOMES

# %%
import os
from common_functions import *
os.chdir("../..")
from dotenv import load_dotenv
load_dotenv(), print(os.getenv("GOOGLE_APPLICATION_CREDENTIALS"),os.getcwd())
from sibr_module import Logger, CStorage
import re
import numpy as np
import ast

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('future.no_silent_downcasting', True)
from src.helper_modules import CustomBigQuery
from src.sibr_market_training import Clean
# Out:
# sibr-market-18334b5d01a1.json /Users/sigvardbratlie/PycharmProjects/sibr-market-backend/modeling

# %%
replace = True
dataset = 'homes'
logger = Logger(f'clean{dataset.capitalize()}')
logger.log_level = "DEBUG"
bq = CustomBigQuery(logger=logger, dataset=dataset)
cs = CStorage(logger=logger, bucket_name='sibr-market-bucket')
logger.debug(f'Replace: {replace} | Dataset: {dataset}')
self = Clean(logger=logger, dataset=dataset)
# Out:
# 2025-09-23 11:06:47,096 - cleanHomes - INFO - Cloud Logging is disabled. Using local logging to /Users/sigvardbratlie/PycharmProjects/sibr-market-backend/logfiles/cleanHomes.log.
# 2025-09-23 11:06:47,181 - cleanHomes - INFO - BigQuery client initialized with project_id: sibr-market
# 2025-09-23 11:06:47,249 - cleanHomes - INFO - Google Cloud Storage client initialized with bucket: sibr-market-bucket
# 2025-09-23 11:06:47,249 - cleanHomes - DEBUG - Replace: True | Dataset: homes
# 2025-09-23 11:06:47,316 - cleanHomes - INFO - BigQuery client initialized with project_id: sibr-market
# 2025-09-23 11:06:47,381 - cleanHomes - INFO - Google Cloud Storage client initialized with bucket: sibr-market
# 2025-09-23 11:06:47,382 - cleanHomes - DEBUG - Dataset: homes | | Replace: False
# 2025-09-23 11:06:47,382 - cleanHomes - INFO - Clean class initialized.

# %%
dataset = "new_homes"
limit = 10000
if replace:
    sql = f'''
                SELECT
                    t.*
                FROM
                  (SELECT
                        *,
                        ROW_NUMBER() OVER(PARTITION BY item_id ORDER BY scrape_date DESC) as rn
                      FROM sibr-market.raw.{dataset}) t
                WHERE t.rn = 1
        '''
else:
    sql = f'''
                SELECT
                t.*
            FROM
              (SELECT
                    *,
                    ROW_NUMBER() OVER(PARTITION BY item_id ORDER BY scrape_date DESC) as rn
                  FROM sibr-market.raw.{dataset}) t
            LEFT JOIN sibr-market.clean.{dataset} h ON t.item_id = h.item_id
            WHERE t.rn = 1
            AND t.scrape_date = (SELECT MAX(scrape_date) FROM sibr-market.raw.{dataset})
            ORDER BY scrape_date DESC
    '''
if limit:
    sql += f' LIMIT {limit}'
self.logger.info(f"Reading raw data from dataset: raw.{dataset}")
df_ = bq.read_bq(sql)
# Out:
# 2025-09-23 11:20:53,586 - cleanHomes - INFO - Reading raw data from dataset: raw.new_homes
# 2025-09-23 11:20:57,090 - cleanHomes - INFO - 10000 rader lest fra BigQuery

# %%
#df_ = bq.read_raw(replace=replace)
geo = bq.read_geonorge()
# Out:
# 2025-09-23 11:09:13,069 - cleanHomes - INFO - 5137 rader lest fra BigQuery

# %%
df_[["coop_org_num","url"]]
# Out:
#      coop_org_num                                                url
# 0              []  https://www.finn.no/realestate/projectunit/ad....
# 1              []  https://www.finn.no/realestate/projectunit/ad....
# 2              []  https://www.finn.no/realestate/projectunit/ad....
# 3              []  https://www.finn.no/realestate/projectunit/ad....
# 4              []  https://www.finn.no/realestate/projectunit/ad....
# ...           ...                                                ...
# 9995           []  https://www.finn.no/realestate/projectunit/ad....
# 9996           []  https://www.finn.no/realestate/projectsingle/a...
# 9997           []  https://www.finn.no/realestate/projectunit/ad....
# 9998           []  https://www.finn.no/realestate/projectunit/ad....
# 9999           []  https://www.finn.no/realestate/projectunit/ad....
#
# [10000 rows x 2 columns]

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 52 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   item_id              10000 non-null  object
#  1   title                10000 non-null  object
#  2   description          10000 non-null  object
#  3   url                  10000 non-null  object
#  4   address              10000 non-null  object
#  5   last_updated         10000 non-null  object
#  6   country              10000 non-null  object
#  7   dealer               10000 non-null  object
#  8   contact_person       10000 non-null  object
#  9   phone                10000 non-null  object
#  10  email                10000 non-null  object
#  11  web                  10000 non-null  object
#  12  price                10000 non-null  object
#  13  total_price          10000 non-null  object
#  14  fees                 10000 non-null  object
#  15  joint_debt           10000 non-null  object
#  16  monthly_common_cost  10000 non-null  object
#  17  collective_assets    10000 non-null  object
#  18  tax_value            10000 non-null  object
#  19  new                  10000 non-null  object
#  20  district             10000 non-null  object
#  21  property_type        10000 non-null  object
#  22  ownership_type       10000 non-null  object
#  23  bedrooms             10000 non-null  object
#  24  rooms                10000 non-null  object
#  25  floor                10000 non-null  object
#  26  balcony              10000 non-null  object
#  27  build_year           10000 non-null  object
#  28  energy_rating        10000 non-null  object
#  29  primary_area         10000 non-null  object
#  30  usable_area          10000 non-null  object
#  31  internal_area        10000 non-null  object
#  32  external_area        10000 non-null  object
#  33  plot_size            10000 non-null  object
#  34  plot                 10000 non-null  object
#  35  seller_insurance     10000 non-null  object
#  36  facilities           10000 non-null  object
#  37  planning             10000 non-null  object
#  38  sales_start          10000 non-null  object
#  39  construction_start   10000 non-null  object
#  40  completion           10000 non-null  object
#  41  cadastral_num        9915 non-null   object
#  42  unit_num             9915 non-null   object
#  43  section_num          9915 non-null   object
#  44  municipality_num     8265 non-null   object
#  45  coop_unit_num        8265 non-null   object
#  46  scrape_date          10000 non-null  object
#  47  leasehold_num        8265 non-null   object
#  48  apartment_num        8265 non-null   object
#  49  coop_org_num         8265 non-null   object
#  50  coop_name            8265 non-null   object
#  51  rn                   10000 non-null  int64
# dtypes: int64(1), object(51)
# memory usage: 4.0+ MB

# %%
self.df = df_
self.geo = geo

# %%
df = self.transform_nan(self.df)
df = self.rm_empty_features(df)
self.logger.debug(f'Length: {len(df)} | after merge with sales time')

int_cols = [
    'price', 'balcony', 'total_price', 'bedrooms', 'rooms', 'build_year',
    'usable_area', 'internal_area', 'external_area', 'plot_size', 'fees',
    'joint_debt', 'monthly_common_cost', 'collective_assets', 'tax_value', 'floor'
]
df = self.mk_num(df, int_cols, type='int')

cadastre_fields = ["cadastral_num", "unit_num", "section_num","coop_unit_num","municipality_num","coop_org_num","leasehold_num"]

def fix_cadastre(x):
    val = ast.literal_eval(x)
    if isinstance(val, list):
        for e in val:
            res = self.extract_int(e)
            if res is not None:
                return res
    else:
        self.logger.warning(f'Unexpected dtype {type(val)} | {val} for cadastre field. Expecting list')
        return val
for field in cadastre_fields:
    df.loc[:,field] = df[field].apply(lambda x: fix_cadastre(x) if isinstance(x, str) else x)
    df[field] = pd.to_numeric(df[field], errors='coerce')
# Out:
# 2025-09-23 11:21:22,869 - cleanHomes - DEBUG - Length of df before cleaning: 10000
# 2025-09-23 11:21:22,990 - cleanHomes - DEBUG - Length: 10000 | after removing columns with >90% missing values
# 2025-09-23 11:21:22,990 - cleanHomes - DEBUG - Length: 10000 | after merge with sales time
# 2025-09-23 11:21:23,039 - cleanHomes - WARNING - Column "build_year" not found in dataframe.
# 2025-09-23 11:21:23,066 - cleanHomes - WARNING - Column "plot_size" not found in dataframe.
# 2025-09-23 11:21:23,067 - cleanHomes - WARNING - Column "fees" not found in dataframe.
# 2025-09-23 11:21:23,067 - cleanHomes - WARNING - Column "joint_debt" not found in dataframe.
# 2025-09-23 11:21:23,075 - cleanHomes - WARNING - Column "collective_assets" not found in dataframe.
# 2025-09-23 11:21:23,075 - cleanHomes - WARNING - Column "tax_value" not found in dataframe.

# %%
df['total_price'] = df['total_price'].astype('float')
df['total_price'] = df['total_price'].fillna(df['price'].astype('float') * 1.025)
# If you want to keep it as Int64 after filling:
df['total_price'] = df['total_price'].round().astype('Int64')
df.loc[:, 'bedrooms'] = df['bedrooms'].fillna(0)
df['bedrooms'] = df['bedrooms'].fillna(0)
df['external_area'] = df['external_area'].fillna(0)
df['internal_area'] = df['internal_area'].fillna(df['usable_area'] - df['external_area'])
df['usable_area'] = df['usable_area'].fillna(df['internal_area'])
df['internal_area'] = df['internal_area'].fillna(df['usable_area'])
df['floor'] = df['floor'].fillna(0)

df = self.mk_fractions(df=df, new_feat_name='price_pr_sqm',numerator='price',denominator='usable_area')
df = self.mk_fractions(df=df, new_feat_name='price_pr_i_sqm', numerator='price', denominator='internal_area')
df = self.mk_fractions(df=df, new_feat_name='price_pr_bedroom',numerator='price',denominator='bedrooms')
df = self.mk_fractions(df=df, new_feat_name='sqm_pr_bedroom',numerator='usable_area',denominator='bedrooms')
df = self.mk_fractions(df=df, new_feat_name='monthly_common_cost_pr_sqm', numerator='monthly_common_cost', denominator='usable_area')
df['sqm_pr_bedroom'] = df['sqm_pr_bedroom'].fillna(df['usable_area'])

df.drop('primary_area', axis=1, inplace=True, errors='ignore')

df = df[(df['price'] > 200000) & (df['price'] < 30000000)
        & ((df['usable_area'] > 0) & (df['usable_area'] < 1500))
        & ((df['internal_area'] > 0) & (df['internal_area'] < 1500))
        & ((df['bedrooms'] >= 0) & (df['bedrooms'] < 10))
        & ((df['floor'] >= 0) & (df['floor'] < 100))
        & ((df['total_price'] >= 0) & (df['total_price'] < 35000000))
        ]
self.logger.debug(f'Length: {len(df)} | after filter price and usable_area')

df['scrape_date'] = pd.to_datetime(df['scrape_date'], errors='coerce', utc=True)
df['clean_date'] = pd.Timestamp.now()
self.logger.debug(f'Length: {len(df)} | after datetime conversion')

df['postal_code'] = df['address'].apply(self.extract_postnummer)
df = pd.merge(df, self.geo[['postal_code', 'municipality', 'county', 'region']], how='left', on='postal_code')
self.logger.debug(f'Length: {len(df)} | after geo')

df['ownership_type'] = df['ownership_type'].str.replace(r'^eieform', '', case=False, regex=True).str.strip()
df['ownership_type'] = df['ownership_type'].apply(
    lambda x: x.replace('(Selveier)', "").strip() if isinstance(x, str) else x)
df['property_type'] = df['property_type'].str.replace(r'^boligtype', '', case=False, regex=True)
df['property_type'] = df['property_type'].apply(lambda x: x.replace('/', "_") if isinstance(x, str) else x).str.strip()
df['dealer'] = df['dealer'].fillna('private').str.strip()

equipment_features = {
    'eq_parking': ["parkering", "p-plass", "parkeringsplass", "garasje/p-plass"],
    "eq_lift": ["heis", "løfteplattform"],
    "eq_fireplace": ['peis', "peis/ildsted"],
    "eq_charging_possibility": ["lademulighet"],
    "eq_aircondition": ["aircondition"],
    "eq_garden": ["hage"],
    "eq_pool": ["badebasseng", "basseng", "boblebad", "jacuzzi"]
}
df = self.mk_bool_features(df=df, equipment_features=equipment_features, source_col="facilities")

df = self.mk_bool_description(df=df,
                           col_name="eq_parking_tmp",
                           keys=["parkering", "p-plass", "parkeringsplass", "garasje/p-plass"],
                           source_cols=["description", "title"])
df = self.mk_bool_description(df=df,
                           col_name="eq_lift_tmp",
                           keys=["heis", "løfteplattform"],
                           source_cols=["description", "title"])
df = self.mk_bool_description(df=df,
                           col_name="eq_pool_tmp",
                           keys=["badebasseng", "basseng", "boblebad", "jacuzzi"],
                           source_cols=["description", "title"])

df['eq_parking'] = df.apply(lambda row: True if row['eq_parking_tmp'] or row['eq_parking'] else False, axis=1)
df['eq_lift'] = df.apply(lambda row: True if row['eq_lift_tmp'] or row['eq_lift'] else False, axis=1)
df['eq_pool'] = df.apply(lambda row: True if row['eq_pool_tmp'] or row['eq_pool'] else False, axis=1)
df.drop(columns=['eq_parking_tmp', 'eq_lift_tmp', "eq_pool_tmp"], inplace=True, errors="ignore")

keys_fixer_upper = [
    'oppussingsobjekt', 'oppussingsbehov', 'oppussingsklar', 'renoveringsobjekt', 'oppgraderingsobjekt',
    'renoveringsbehov', 'moderniseringsbehov', 'moderniseringsobjekt', 'oppgraderingsbehov',
    'rehabilitering/oppussing', 'rehabilitering', 'oppussing', 'oppgradering og vedlikehold',
    'rehabiliteringsbehov'
]
keys_renovated = [
    'nylig oppusset', 'nyoppusset', 'totalrenovert', 'pusset opp', 'renovert',
    'totalrehabilitert', "oppusset"
]
df = self.mk_bool_description(df=df,
                           col_name='fixer_upper',
                           keys=keys_fixer_upper,
                           source_cols=['description', 'title'])
df = self.mk_bool_description(df=df,
                           col_name="renovated",
                           keys=keys_renovated,
                           source_cols=['description', 'title'])
df = self.mk_bool_description(df=df,
                           col_name='eq_rental_unit',
                           keys=["utleiedel", "utleiebolig", "utleieenhet", "utleie del", "utleie bolig",
                                 "utleie enhet", "anneks"],
                           source_cols=['description', 'title'])
df = self.mk_bool_description(df=df,
                           col_name="eq_west_facing",
                           keys=["vestvendt terrasse", "vestvendt", "vestvendt balkong"],
                           source_cols=["description", "title"])
df = self.mk_bool_description(df=df,
                           col_name="eq_sauna",
                           keys=["badstue", "sauna"],
                           source_cols=["description", "title"])

if 'sold' in df.columns:
    df['sold'] = df['sold'].str.lower().str.strip()
    df['sold'] = df['sold'].apply(lambda x: True if pd.notna(x) and x == 'solgt' else False)
    df['sold'] = df['sold'].fillna(False)
    df['sold'] = df['sold'].astype('boolean')
self.logger.debug(f'Length: {len(df)} | after boolean')

df.loc[:, "last_updated"] = df["last_updated"].apply(
    lambda x: self.extract_datetime(x) if isinstance(x, str) else x)
df["last_updated"] = pd.to_datetime(df["last_updated"])

extra_cols = ['email', 'web']
df = self.add_missing_features(df, extra_cols)

df = self.ensure_num_types(df, num_types=['int', 'float'])

self.logger.debug(f'Length: {len(df)} | before saving to BQ. Replace {self.replace}')
self.df = df
# Out:
# 2025-09-23 11:21:26,130 - cleanHomes - DEBUG - Length: 9312 | after filter price and usable_area
# 2025-09-23 11:21:26,132 - cleanHomes - DEBUG - Length: 9312 | after datetime conversion
# 2025-09-23 11:21:26,146 - cleanHomes - DEBUG - Length: 9312 | after geo
# 2025-09-23 11:21:35,208 - cleanHomes - DEBUG - Length: 9312 | after boolean
# 2025-09-23 11:21:35,520 - cleanHomes - DEBUG - Length: 9312 | before saving to BQ. Replace False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9312 entries, 0 to 9311
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   item_id                     9312 non-null   object
#  1   title                       9312 non-null   object
#  2   description                 9312 non-null   object
#  3   url                         9312 non-null   object
#  4   address                     9312 non-null   object
#  5   last_updated                9216 non-null   datetime64[ns]
#  6   country                     9312 non-null   object
#  7   dealer                      9312 non-null   object
#  8   contact_person              9312 non-null   object
#  9   phone                       9294 non-null   object
#  10  email                       9312 non-null   object
#  11  web                         5571 non-null   object
#  12  price                       9312 non-null   Int64
#  13  total_price                 9312 non-null   Int64
#  14  monthly_common_cost         4610 non-null   Int64
#  15  new                         9312 non-null   object
#  16  district                    9312 non-null   object
#  17  property_type               9312 non-null   object
#  18  ownership_type              1979 non-null   object
#  19  bedrooms                    9312 non-null   Int64
#  20  rooms                       5618 non-null   Int64
#  21  floor                       9312 non-null   Int64
#  22  balcony                     4310 non-null   Int64
#  23  energy_rating               1534 non-null   object
#  24  usable_area                 9312 non-null   Int64
#  25  internal_area               9312 non-null   Int64
#  26  external_area               9312 non-null   Int64
#  27  facilities                  9312 non-null   object
#  28  planning                    9312 non-null   object
#  29  sales_start                 9312 non-null   object
#  30  construction_start          9312 non-null   object
#  31  completion                  9312 non-null   object
#  32  cadastral_num               6321 non-null   Float64
#  33  unit_num                    6202 non-null   Float64
#  34  section_num                 1474 non-null   Float64
#  35  municipality_num            6202 non-null   Float64
#  36  coop_unit_num               0 non-null      Float64
#  37  scrape_date                 9312 non-null   datetime64[ns, UTC]
#  38  leasehold_num               91 non-null     Float64
#  39  apartment_num               7712 non-null   object
#  40  coop_org_num                0 non-null      Float64
#  41  coop_name                   7712 non-null   object
#  42  rn                          9312 non-null   Int64
#  43  price_pr_sqm                9312 non-null   Float64
#  44  price_pr_i_sqm              9312 non-null   Float64
#  45  price_pr_bedroom            9119 non-null   Float64
#  46  sqm_pr_bedroom              9312 non-null   Float64
#  47  monthly_common_cost_pr_sqm  4610 non-null   Float64
#  48  clean_date                  9312 non-null   datetime64[us]
#  49  postal_code                 9312 non-null   object
#  50  municipality                9288 non-null   object
#  51  county                      9288 non-null   object
#  52  region                      9288 non-null   object
#  53  eq_parking                  9312 non-null   bool
#  54  eq_lift                     9312 non-null   bool
#  55  eq_fireplace                9312 non-null   bool
#  56  eq_charging_possibility     9312 non-null   bool
#  57  eq_aircondition             9312 non-null   bool
#  58  eq_garden                   9312 non-null   bool
#  59  eq_pool                     9312 non-null   bool
#  60  fixer_upper                 9312 non-null   boolean
#  61  renovated                   9312 non-null   boolean
#  62  eq_rental_unit              9312 non-null   boolean
#  63  eq_west_facing              9312 non-null   boolean
#  64  eq_sauna                    9312 non-null   boolean
# dtypes: Float64(12), Int64(11), bool(7), boolean(5), datetime64[ns, UTC](1), datetime64[ns](1), datetime64[us](1), object(27)
# memory usage: 4.1+ MB

# %% [markdown]
# ## Remove empty feature and missing data

# %%
c.logger.debug(f'Length of df before cleaning: {len(df_)}')
c.df = df_
df = c.transform_nan(df_)
df.drop_duplicates(subset=['item_id'], inplace=True)
df = c.rm_empty_features(df)
c.logger.debug(f'Length: {len(df)} | after removing NaN values and duplicates')
# Out:
# 2025-08-27 10:33:17,512 - cleanHomes - DEBUG - Length of df before cleaning: 176875
# 2025-08-27 10:33:17,513 - cleanHomes - DEBUG - Length of df before cleaning: 176875
# 2025-08-27 10:33:19,452 - cleanHomes - DEBUG - Length: 176875 | after removing columns with >90% missing values
# 2025-08-27 10:33:19,453 - cleanHomes - DEBUG - Length: 176875 | after removing NaN values and duplicates

# %% [markdown]
# ## Int and Float data

# %%
import re
import ast
def extract_int(x):
    """
    Extracts an integer from a string.

    Args:
        x (str): The input value from which to extract the number.
    Returns:
        int or None: The extracted integer, or None if no valid number can be extracted.

    Examples
        "200.000" : str -> 200000 : int
        "200,000" : str -> 200000 : int
        "200m2" : str -> 200 : int
        "2000,0 : str -> 2000000 : int
        "435,5 kr : srt -> 435500 : int
    """
    if not isinstance(x, str):
        return None
    uten_mellomrom = re.sub(r'\s', '', x)
    match = re.search(r'[\d.,]+', uten_mellomrom)
    if not match:
        return None
    nummer_str = match.group(0)
    has_separator = '.' in nummer_str or ',' in nummer_str
    # Parse to float using similar logic as extract_float
    if ',' in nummer_str and '.' in nummer_str:
        if nummer_str.rfind(',') > nummer_str.rfind('.'):
            nummer_str_parsed = nummer_str.replace('.', '').replace(',', '.')
        else:
            nummer_str_parsed = nummer_str.replace(',', '')
    elif ',' in nummer_str:
        nummer_str_parsed = nummer_str.replace(',', '.')
    else:
        nummer_str_parsed = nummer_str
    try:
        nummer_float = float(nummer_str_parsed)
    except (ValueError, TypeError):
        return None
    if not has_separator:
        if nummer_float.is_integer():
            return int(nummer_float)
        else:
            return None
    else:
        # Multiply by 1000 and round to int
        multiplied = nummer_float * 1000
        return int(round(multiplied))

def extract_float(x):
    """
    Extracts  a float number from a string.

    Args:
        x (str): The input value from which to extract the number.
    Returns:
        float or None: The extracted floating number, or None if no valid number can be extracted.

    Examples
        "200.000" : str -> 200.0 : float
        "200,000" : str -> 200.0 : float
        "200m2" : str -> 200.0 : float
        "2000,0 : str -> 2000.0 : float
        "435,5 kr : srt -> 435.5 : float
            """
    if not isinstance(x, str):
        return None
    uten_mellomrom = re.sub(r'\s', '', x)
    match = re.search(r'[\d.,]+', uten_mellomrom)
    if not match:
        return None
    nummer_str = match.group(0)
    if ',' in nummer_str and '.' in nummer_str:
        if nummer_str.rfind(',') > nummer_str.rfind('.'):
            nummer_str = nummer_str.replace('.', '').replace(',', '.')
        else:
            nummer_str = nummer_str.replace(',', '')
    elif ',' in nummer_str:
        nummer_str = nummer_str.replace(',', '.')
    try:
        return float(nummer_str)
    except (ValueError, TypeError):
        return None

# %%
# Out:
# 0         ['Gårdsnr', ': ', '186']
# 1                             None
# 2           ['Gårdsnr', ': ', '9']
# 3                             None
# 4          ['Gårdsnr', ': ', '20']
#                     ...
# 176870     ['Gårdsnr', ': ', '36']
# 176871    ['Gårdsnr', ': ', '144']
# 176872     ['Gårdsnr', ': ', '62']
# 176873     ['Gårdsnr', ': ', '61']
# 176874    ['Gårdsnr', ': ', '185']
# Name: cadastral_num, Length: 176875, dtype: object

# %%
cadastre_fields = ["cadastral_num", "unit_num", "section_num","coop_unit_num","municipality_num","coop_org_num","leasehold_num"]

def fix_cadastre(x):
    val = ast.literal_eval(x)
    if isinstance(val, list):
        #print(f'Instance {val} is list')
        for e in val:
            res = self.extract_int(e)
            if res is not None:
                #print(f'Extracted {e} -> {res} to int')
                return res
    else:
        print(f'Instance {val} is not list')
        return val
for field in cadastre_fields:
    df.loc[:,field] = df[field].apply(lambda x: fix_cadastre(x) if isinstance(x, str) else x)
    df[field] = pd.to_numeric(df[field],errors='coerce')

# %%
df["cadastral_num"] = pd.to_numeric(df["cadastral_num"], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176875 entries, 0 to 176874
# Data columns (total 46 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dealer               170241 non-null  object
#  1   district             115436 non-null  object
#  2   address              176874 non-null  object
#  3   price                176362 non-null  object
#  4   total_price          175447 non-null  object
#  5   fees                 169249 non-null  object
#  6   joint_debt           60733 non-null   object
#  7   monthly_common_cost  104908 non-null  object
#  8   collective_assets    62630 non-null   object
#  9   tax_value            147612 non-null  object
#  10  property_type        176548 non-null  object
#  11  ownership_type       176856 non-null  object
#  12  bedrooms             174156 non-null  object
#  13  internal_area        164035 non-null  object
#  14  usable_area          173306 non-null  object
#  15  external_area        130411 non-null  object
#  16  floor                118581 non-null  object
#  17  balcony              123813 non-null  object
#  18  build_year           169085 non-null  object
#  19  energy_rating        145750 non-null  object
#  20  rooms                122724 non-null  object
#  21  plot_size            160340 non-null  object
#  22  last_updated         176871 non-null  object
#  23  item_id              176874 non-null  object
#  24  title                176874 non-null  object
#  25  sold                 151366 non-null  object
#  26  description          162447 non-null  object
#  27  email                156795 non-null  object
#  28  contact_person       166282 non-null  object
#  29  phone                156771 non-null  object
#  30  url                  176822 non-null  object
#  31  country              176875 non-null  object
#  32  web                  96388 non-null   object
#  33  new                  158348 non-null  object
#  34  facilities           158348 non-null  object
#  35  cadastral_num        156029 non-null  float64
#  36  unit_num             156008 non-null  float64
#  37  section_num          62117 non-null   float64
#  38  municipality_num     147535 non-null  float64
#  39  coop_unit_num        40141 non-null   float64
#  40  scrape_date          176875 non-null  object
#  41  coop_name            124659 non-null  object
#  42  coop_org_num         40717 non-null   float64
#  43  apartment_num        124659 non-null  object
#  44  leasehold_num        1066 non-null    float64
#  45  rn                   176875 non-null  int64
# dtypes: float64(7), int64(1), object(38)
# memory usage: 62.1+ MB

# %%
int_cols = ['price','balcony', 'total_price','bedrooms', 'rooms', 'build_year',
            #'primary_area',
            'usable_area',
            'internal_area', 'external_area', 'plot_size','fees', 'joint_debt', 'monthly_common_cost',
              'collective_assets', 'tax_value','floor']


df = c.mk_num(df, int_cols, type='int')

df['total_price'] = df['total_price'].astype('float')
df['total_price'] = df['total_price'].fillna(df['price'].astype('float') * 1.025)
# If you want to keep it as Int64 after filling:
df['total_price'] = df['total_price'].round().astype('Int64')
df.loc[:, 'bedrooms'] = df['bedrooms'].fillna(0)
df['bedrooms'] = df['bedrooms'].fillna(0)
df['external_area'] = df['external_area'].fillna(0)
df['internal_area'] = df['internal_area'].fillna(df['usable_area']- df['external_area'])
df['usable_area'] = df['usable_area'].fillna(df['internal_area'])
df['internal_area'] = df['internal_area'].fillna(df['usable_area'])
df['floor'] = df['floor'].fillna(0)

df = c.mk_fractions(df=df, new_feat_name='price_pr_sqm',numerator='price',denominator='usable_area')
df = c.mk_fractions(df=df,new_feat_name = 'price_pr_i_sqm',numerator='price',denominator='internal_area')
df = c.mk_fractions(df=df, new_feat_name='price_pr_bedroom',numerator='price',denominator='bedrooms')
df = c.mk_fractions(df=df, new_feat_name='sqm_pr_bedroom',numerator='usable_area',denominator='bedrooms')

df.drop('primary_area', axis=1, inplace=True, errors='ignore')

df = df[(df['price']>200000) & (df['price']<30000000)
        & ((df['usable_area']>0) & (df['usable_area']<1500))
        & ((df['internal_area']>0) & (df['internal_area']<1500))
         & ((df['bedrooms']>=0) & (df['bedrooms']<10))
        & ((df['floor']>=0) & (df['floor']<100))
        & ((df['total_price']>=0) & (df['total_price']<35000000))
        ]
c.logger.debug(f'Length: {len(df)} | after filter price and usable_area')
# Datetime Data
# Out:
# 2025-08-02 12:47:00,037 - cleanHomes - DEBUG - Length: 161508 | after filter price and usable_area

# %%
df['scrape_date'] = pd.to_datetime(df['scrape_date'],errors='coerce',utc=True)
df['clean_date'] = pd.Timestamp.now()
c.logger.debug(f'Length: {len(df)} | after datetime conversion')
# Out:
# /var/folders/qv/k9q4x60x4wn1fy68fsy_wtl00000gn/T/ipykernel_80800/1177034425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scrape_date'] = pd.to_datetime(df['scrape_date'],errors='coerce',utc=True)
# /var/folders/qv/k9q4x60x4wn1fy68fsy_wtl00000gn/T/ipykernel_80800/1177034425.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_date'] = pd.Timestamp.now()
# 2025-08-02 12:47:03,415 - cleanHomes - DEBUG - Length: 161508 | after datetime conversion

# %% [markdown]
# ## Geographical data

# %%
df.loc[:,'postal_code'] = df['address'].apply(c.extract_postnummer)
df = pd.merge(df,geo[['postal_code','municipality','county','region']],how='left',on='postal_code')
c.logger.debug(f'Length: {len(df)} | after geo')
# Out:
# /var/folders/qv/k9q4x60x4wn1fy68fsy_wtl00000gn/T/ipykernel_80800/1593316539.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'postal_code'] = df['address'].apply(c.extract_postnummer)
# 2025-08-02 12:47:25,064 - cleanHomes - DEBUG - Length: 161508 | after geo

# %% [markdown]
# ## Categorical Data

# %%
df['ownership_type'] = df['ownership_type'].str.replace(r'^eieform', '', case=False, regex=True)
df['ownership_type'] = df['ownership_type'].apply(lambda x: x.replace('(Selveier)',"") if isinstance(x,str) else x)
df['property_type'] = df['property_type'].str.replace(r'^boligtype', '', case=False, regex=True)
# df['property_type'] = df['property_type'].str.replace(r'\s*/småbruk', '', case=False, regex=True)
# df['property_type'] = df['property_type'].str.replace(r'\s*/flermannsbolig', '', case=False, regex=True)
# df['property_type'] = df['property_type'].str.replace(r'/$', '', regex=True)
df['property_type'] = df['property_type'].apply(lambda x: x.replace('/',"_") if isinstance(x, str) else x)
df['dealer'] = df['dealer'].fillna('private')
c.logger.debug(f'Length: {len(df)} | after categorical')
# Out:
# 2025-08-02 12:52:10,792 - cleanHomes - DEBUG - Length: 161508 | after categorical

# %%
df[["cadastral_num","unit_num","section_num"]]
# Out:
#        cadastral_num  unit_num  section_num
# 0                 53        17         <NA>
# 1                 15        86         <NA>
# 2                422       334         <NA>
# 3                 17       244         <NA>
# 4                  3         7         <NA>
# ...              ...       ...          ...
# 18732            234       123         <NA>
# 18733             41       863          130
# 18734            212       195         <NA>
# 18735            224        29         <NA>
# 18736            300      4576         <NA>
#
# [18737 rows x 3 columns]

# %%
df['description'].iloc[1000],df["url"].iloc[1000]
# Out:
# ("['Fellesutgiftene er kr 700,- pr. mnd. og inkluderer: ', '- Drift av snøfreser', '- Forsikring', 'Fellesutgiftene justeres normalt en til to ganger årlig i forhold til sameiets faktiske utgifter.', 'Det tas forbehold om at felleskostnadene kan justeres fortløpende pga renteøkninger.', 'Nåværende eier har et strømforbruk som tilsvarer ca. kr 9.500,- pr. år. / 6.359 kwh. pr. år.', 'Selger har egen ruter fra Pluss Mobil som leverer internett i dag. Selger sier opp abonnement.  Selger opplyser om at det etter planen vil bli lagt inn fiber av Viken Fiber til sommeren. Det tas forbehold om endringer. ', 'Boligen er ikke tilknyttet alarmselskap. ', 'Utgiftene er basert på nåværende eiers forbruk. Kjøper må selv tegne innboforsikring.', '3 390 000,00 Prisantydning', '\\xa0', 'Omkostninger', '\\xa0', '84 750,00\\xa0\\xa0Dokumentavgift til staten (2,5% av kjøpesum)', '9 950,00\\xa0\\xa0Gjensidige Boligkjøperpakke (valgfri)', '545,00\\xa0\\xa0Tinglysing panterettsdokument', '545,00\\xa0\\xa0Tinglysing skjøte', '--------------------------------------------------------', '95 790,00 Omkostninger totalt', '\\xa0', '--------------------------------------------------------', '3\\xa0485\\xa0790,00 Totalpris inkl. omkostninger', '\\xa0', '--------------------------------------------------------', '\\xa0', 'Velkommen til Vestliveien 29B!', 'Pen og strøken leilighet fra 2023. Leiligheten har en god planløsning og kommer med en stor og flott terrasse.  Leiligheten kommer med et pent kjøkken med integrerte hvitevarer. Eiendommen ligger i et hyggelig nabolag med kort vei til diverse forretninger og serveringssted i Åros sentrum, med bussavgang i retning Oslo og Drammen. Kort veo til Oslofjorden med flotte badestrender og marka med flott turterreng. ', '- Det minste soverommet er byggemeldt som bod/ikke godkjent til varig opphold ', '- Stor terrasse', '- Ekstra lydisolering opp mot 2.etg', '- Gulvvarme i stue, entre og bad/vaskerom', '- Meget god standard ', '- Kun bebodd i 1.5 år', '- Pent flislagt bad', '- Parkeringsplass utenfor leiligheten']",
#  'https://www.finn.no/realestate/homes/ad.html?finnkode=403273220')

# %%
df["description"].apply(lambda x: x.split())

# %% [markdown]
# ## Boolean data

# %%
equipment_features = {
            'eq_parking' : ["parkering","p-plass","parkeringsplass","garasje/p-plass"],
            "eq_lift" : ["heis","løfteplattform"],
            "eq_fireplace" : ['peis',"peis/ildsted"],
            "eq_charging_possibility" : ["lademulighet"],
            "eq_aircondition" : ["aircondition"],
            "eq_garden" : ["hage"],
            "eq_pool" : ["badebasseng","basseng","boblebad","jacuzzi"]
        }
df = c.mk_bool_features(df= df, equipment_features=equipment_features,source_col="facilities")

df = c.mk_bool_description(df = df ,
                           col_name="eq_parking_tmp",
                           keys = ["parkering","p-plass","parkeringsplass","garasje/p-plass"],
                           source_cols=["description","title"])
df = c.mk_bool_description(df = df ,
                           col_name="eq_lift_tmp",
                           keys = ["heis","løfteplattform"],
                           source_cols=["description","title"])
df = c.mk_bool_description(df = df ,
                           col_name="eq_pool_tmp",
                           keys = ["badebasseng","basseng","boblebad","jacuzzi"],
                           source_cols=["description","title"])

df['eq_parking'] = df.apply(lambda row : True if row['eq_parking_tmp'] or row['eq_parking'] else False, axis=1)
df['eq_lift'] = df.apply(lambda row : True if row['eq_lift_tmp'] or row['eq_lift'] else False, axis=1)
df['eq_pool'] = df.apply(lambda row : True if row['eq_pool_tmp'] or row['eq_pool'] else False, axis=1)
df.drop(columns=['eq_parking_tmp','eq_lift_tmp',"eq_pool_tmp"], inplace=True,errors = "ignore")

keys_fixer_upper = [
        'oppussingsobjekt', 'oppussingsbehov', 'oppussingsklar','renoveringsobjekt','oppgraderingsobjekt',
        'renoveringsbehov', 'moderniseringsbehov','moderniseringsobjekt','oppgraderingsbehov','rehabilitering/oppussing', 'rehabilitering','oppussing','oppgradering og vedlikehold','rehabiliteringsbehov'
        ]
keys_renovated = [
    'nylig oppusset', 'nyoppusset', 'totalrenovert', 'pusset opp', 'renovert',
    'totalrehabilitert',"oppusset"
]
df = c.mk_bool_description(df = df,
                           col_name = 'fixer_upper',
                           keys=keys_fixer_upper,
                           source_cols = ['description','title'])
df = c.mk_bool_description(df = df,
                           col_name = "renovated",
                           keys=keys_renovated,
                           source_cols = ['description','title'])
df = c.mk_bool_description(df = df,
                           col_name  = 'eq_rental_unit',
                           keys = ["utleiedel","utleiebolig","utleieenhet","utleie del", "utleie bolig","utleie enhet","anneks"],
                           source_cols = ['description','title'])
df = c.mk_bool_description(df = df ,
                           col_name="eq_west_facing",
                           keys = ["vestvendt terrasse","vestvendt","vestvendt balkong"],
                           source_cols=["description","title"])
df = c.mk_bool_description(df = df ,
                           col_name="eq_sauna",
                           keys = ["badstue","sauna"],
                           source_cols=["description","title"])


if 'sold' in df.columns:
    df.loc[:,'sold'] = df['sold'].str.lower().str.strip()
    df.loc[:,'sold'] = df['sold'].apply(lambda x: True if pd.notna(x) and x == 'solgt' else False)
    df.loc[:,'sold'] = df['sold'].fillna(False)
    df['sold'] = df['sold'].astype('boolean')
c.logger.debug(f'Length: {len(df)} | after boolean')
# Out:
# 2025-08-08 11:56:49,153 - cleanHomes - DEBUG - Length: 16644 | after boolean

# %%
df["eq_rental_unit"].value_counts()
# Out:
# eq_rental_unit
# False    15698
# True       946
# Name: count, dtype: Int64

# %%
df.loc[:,'FIRST'] = pd.to_datetime(df['FIRST'], errors='coerce', utc=True)
df.loc[:,'LAST'] = pd.to_datetime(df['LAST'], errors='coerce', utc=True)

# %% [markdown]
# # Ensure extra columns

# %%
extra_cols = ['email','web']
df = c.add_missing_features(df = df , missing_features=extra_cols)
df = c.ensure_num_types(df, num_types=['int', 'float'])

# %% [markdown]
# ## Save to BQ

# %%
logger.debug(f'Length: {len(df)} | before saving to BQ. Replace {replace}')
if replace:
    bq.to_bq(df,
             table_name=dataset,
             dataset_name='clean',
             if_exists='replace')
else:
    bq.to_bq(df,
             table_name=dataset,
             dataset_name='clean',
             if_exists='merge',
             merge_on=['item_id'])
# Out:
# 2025-06-24 22:38:25,082 - cleanHomes - DEBUG - Length: 155791 | before saving to BQ. Replace True
# 2025-06-24 22:38:41,926 - cleanHomes - INFO - 155791 rader lagret i sibr-market.clean.homes

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151693 entries, 0 to 155832
# Data columns (total 46 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dealer               115079 non-null  string
#  1   district             30795 non-null   string
#  2   address              151693 non-null  string
#  3   price                151693 non-null  Int64
#  4   total_price          151693 non-null  Int64
#  5   fees                 147199 non-null  Int64
#  6   joint_debt           52948 non-null   Int64
#  7   monthly_common_cost  91513 non-null   float64
#  8   collective_assets    54563 non-null   Int64
#  9   tax_value            128160 non-null  Int64
#  10  property_type        151687 non-null  string
#  11  ownership_type       151683 non-null  string
#  12  bedrooms             151693 non-null  Int64
#  13  internal_area        151693 non-null  Int64
#  14  usable_area          151693 non-null  Int64
#  15  external_area        112090 non-null  Int64
#  16  floor                151693 non-null  Int64
#  17  balcony              106797 non-null  Int64
#  18  build_year           147142 non-null  Int64
#  19  energy_rating        126676 non-null  string
#  20  rooms                106530 non-null  Int64
#  21  plot_size            139382 non-null  Int64
#  22  last_updated         151690 non-null  string
#  23  item_id              151693 non-null  string
#  24  title                151693 non-null  string
#  25  sold                 102533 non-null  string
#  26  description          129393 non-null  string
#  27  email                94366 non-null   string
#  28  contact_person       137386 non-null  string
#  29  phone                94358 non-null   string
#  30  url                  151642 non-null  string
#  31  scrape_date          151693 non-null  string
#  32  country              151693 non-null  string
#  33  web                  18939 non-null   string
#  34  new                  30842 non-null   string
#  35  facilities           30842 non-null   string
#  36  cadastral_num        28194 non-null   string
#  37  unit_num             28194 non-null   string
#  38  section_num          28194 non-null   string
#  39  rn                   151693 non-null  Int64
#  40  FIRST                148250 non-null  date32[day][pyarrow]
#  41  LAST                 148250 non-null  date32[day][pyarrow]
#  42  salgstid             132134 non-null  Int64
#  43  price_pr_sqm         151693 non-null  float64
#  44  price_pr_bedroom     146428 non-null  float64
#  45  sqm_pr_bedroom       146428 non-null  float64
# dtypes: Int64(17), date32[day][pyarrow](2), float64(4), string(23)
# memory usage: 209.4 MB

# %%
df['total_price'].mean()- df['price'].mean()
# Out:
# np.float64(3237659266.28373)

# %%
df.sample(10)
# Out:
#                                      dealer  district  \
# 61260                     Leinæs & Partners  Byskogen
# 104443              EiendomsMegler 1 Horten      <NA>
# 28624                               private      <NA>
# 27798                               private      <NA>
# 89440                               private      <NA>
# 67162                               private      <NA>
# 54364   Heimdal Eiendomsmegling avd. Rosten      <NA>
# 66572                    Aktiv Kristiansund      <NA>
# 134551                              private      <NA>
# 43993               Privatmegleren Komplett      <NA>
#
#                                                   address    price  \
# 61260                           Haukeveien 4, 3258 Larvik  5990000
# 104443                           Tyriveien 3, 3186 Horten  2790000
# 28624                Gamle Lommedalsvei 162, 1348 Rykkinn  6300000
# 27798                           Falkeveien 1D, 3475 Sætre  4990000
# 89440                        Torggata 26, 3211 Sandefjord  2450000
# 67162                           Holtaåsen 16C, 5239 Rådal  7390000
# 54364   Øvre Nyhavna E6-1-02 - Ladebekken 38, 7041 Tro...  5690000
# 66572   Politimester Bendixens gate 18B, 6509 Kristian...  2290000
# 134551                          Vekterveien 93, 0681 Oslo  9290000
# 43993                           Turbinveien 16, 0195 Oslo  5900000
#
#         total_price    fees  joint_debt  monthly_common_cost  \
# 61260     6156240.0  166240        <NA>                  NaN
# 104443    2861136.0   71136           0              0.23100
# 28624     6477500.0  177500        <NA>                  NaN
# 27798     5115750.0  125750        <NA>                  NaN
# 89440     2568455.0   63620       54835           3168.00000
# 67162     7587650.0  197650        <NA>                  NaN
# 54364     5726712.0   36712        <NA>              0.28860
# 66572     2360490.0   70490        <NA>              0.95000
# 134551    9327981.0    8981       29000           3874.00000
# 43993     8606420.0    9302     2697118              0.19806
#
#         collective_assets  tax_value property_type ownership_type  bedrooms  \
# 61260                <NA>    1003088      Enebolig          Eier          6
# 104443               <NA>     660072     Leilighet          Eier          2
# 28624                <NA>    1625000      Enebolig          Eier          3
# 27798                <NA>    1045794      Enebolig          Eier          3
# 89440                <NA>     580942     Leilighet          Eier          1
# 67162                <NA>    1667968  Tomannsbolig          Eier          3
# 54364                <NA>       <NA>     Leilighet          Eier          3
# 66572                <NA>     736735     Leilighet          Eier          1
# 134551              24739    2022838      Rekkehus          Andel         3
# 43993                9480    2068771     Leilighet          Andel         3
#
#         internal_area  usable_area  external_area  floor  balcony  build_year  \
# 61260             194          224             30      0       59        1971
# 104443             71           71           <NA>      2     <NA>        1955
# 28624             166          239             73      0       12        1936
# 27798             135          141              6      0       67        2009
# 89440              63           66              3      3     <NA>        1983
# 67162             160          190             30      0       30        2012
# 54364              85           90              5      1       13        2023
# 66572              78          101             23      1       14        1956
# 134551            157          177             20      3     <NA>        1964
# 43993              94           99              5      8       27        2012
#
#          energy_rating  rooms  plot_size         last_updated    item_id  \
# 61260      E - Oransje   <NA>       1001  17. mars 2025 01:11  366149140
# 104443         E - Rød      4        908  29. jan. 2025 19:48  390333254
# 28624      G - Oransje      4        876  2024-10-03 00:38:00  368486537
# 27798             <NA>      6        343  2024-08-19 17:26:00  356848484
# 89440          E - Rød   <NA>       6968  2024-09-08 05:44:00  368440799
# 67162          B - Gul      5        861  2024-09-20 07:05:00  364587524
# 54364             <NA>      4       <NA>  30. okt. 2024 18:50  352014357
# 66572      G - Oransje      2        306  25. okt. 2024 08:43  355127419
# 134551         C - Rød      4      15953  2024-08-16 11:18:00  365930225
# 43993   D - Mørkegrønn      4       8904   12. mai 2025 14:19  405149249
#
#                                                     title   sold  \
# 61260   Unik arkitekttegnet Hellum enebolig med særege...  False
# 104443                            -solgt- visning avlyst!   True
# 28624   enebolig over 3 plan - terrasse og balkong - d...  False
# 27798   pen kjedet enebolig med carport - 3 soverom; w...  False
# 89440   innholdsrik leilighet med vestvendt balkong mo...  False
# 67162   nydelig familiebolig fra 2012 med flott beligg...  False
# 54364   svært innholdsrik 4-roms hjørneleilighet med s...  False
# 66572   flott og moderne 2-romsleilighet med kontor og...  False
# 134551  stort, utbygd familievennlig rekkehus på 157 k...  False
# 43993   gjennomgående 4-roms toppleilighet på 94 m². s...   True
#
#                                               description  \
# 61260   ['5 990 000,- (Prisantydning)', 'Omkostninger'...
# 104443  Halvpart tomannsboligBRA-i:2. etasje: 71  kvm ...
# 28624   kr 6 300 000,- (Prisantydning)Omkostninger:kr ...
# 27798   I tillegg til kjøpesummen må kjøper betale:- D...
# 89440   Fellesutgiftene er kr 3.168,- pr. mnd. og inkl...
# 67162   BoligBRA-i:2. etasje: 25  kvm Soverom, loftstu...
# 54364   BRA-i:1. etasje: 85  kvmBRA-e:1. etasje: 5  kv...
# 66572   BRA-i:1. etasje: 78  kvm Bad/vaskerom, stue, k...
# 134551  BRA-i:2. etasje: 53  kvm 3 Soverom, bad og 2 b...
# 43993   Renter / avdrag andel fellesgjeld, garasjeleie...
#
#                                    email    contact_person        phone  \
# 61260                  thomas@leinaes.no   Thomas A. Østmo  95 99 40 44
# 104443             tom.lund@em1sorost.no          Tom Lund  91 36 32 77
# 28624                               <NA>          ('', '')         <NA>
# 27798                               <NA>          ('', '')         <NA>
# 89440                               <NA>          ('', '')         <NA>
# 67162                               <NA>          ('', '')         <NA>
# 54364                          mk@hem.no  Morten Kvernland  95 04 25 01
# 66572               erik.ulseth@aktiv.no       Erik Ulseth  99 31 71 91
# 134551                              <NA>          ('', '')         <NA>
# 43993   sander.egerhei@privatmegleren.no    Sander Egerhei  46 61 26 73
#
#                                                       url  \
# 61260   https://www.finn.no/realestate/homes/ad.html?f...
# 104443  https://www.finn.no/realestate/homes/ad.html?f...
# 28624   https://www.finn.no/realestate/homes/ad.html?f...
# 27798   https://www.finn.no/realestate/homes/ad.html?f...
# 89440   https://www.finn.no/realestate/homes/ad.html?f...
# 67162   https://www.finn.no/realestate/homes/ad.html?f...
# 54364   https://www.finn.no/realestate/homes/ad.html?f...
# 66572   https://www.finn.no/realestate/homes/ad.html?f...
# 134551  https://www.finn.no/realestate/homes/ad.html?f...
# 43993   https://www.finn.no/realestate/homes/ad.html?f...
#
#                      scrape_date country   web    new  \
# 61260  2025-06-14 00:00:00+00:00      NO  <NA>  False
# 104443 2025-01-30 00:00:00+00:00      NO  <NA>   <NA>
# 28624  2024-10-03 00:00:00+00:00      NO  <NA>   <NA>
# 27798  2024-08-21 00:00:00+00:00      NO  <NA>   <NA>
# 89440  2024-09-08 00:00:00+00:00      NO  <NA>   <NA>
# 67162  2024-09-22 00:00:00+00:00      NO  <NA>   <NA>
# 54364  2024-10-31 00:00:00+00:00      NO  <NA>   <NA>
# 66572  2024-11-07 00:00:00+00:00      NO  <NA>   <NA>
# 134551 2024-08-18 00:00:00+00:00      NO  <NA>   <NA>
# 43993  2025-05-14 00:00:00+00:00      NO  <NA>   <NA>
#
#                                                facilities  \
# 61260   ['Balkong/Terrasse', 'Peis/Ildsted', 'Barneven...
# 104443                                               <NA>
# 28624                                                <NA>
# 27798                                                <NA>
# 89440                                                <NA>
# 67162                                                <NA>
# 54364                                                <NA>
# 66572                                                <NA>
# 134551                                               <NA>
# 43993                                                <NA>
#
#                     cadastral_num                  unit_num section_num  rn  \
# 61260   ['Gårdsnr', ': ', '3020']  ['Bruksnr', ': ', '681']          []   1
# 104443                       <NA>                      <NA>        <NA>   1
# 28624                        <NA>                      <NA>        <NA>   1
# 27798                        <NA>                      <NA>        <NA>   1
# 89440                        <NA>                      <NA>        <NA>   1
# 67162                        <NA>                      <NA>        <NA>   1
# 54364                        <NA>                      <NA>        <NA>   1
# 66572                        <NA>                      <NA>        <NA>   1
# 134551                       <NA>                      <NA>        <NA>   1
# 43993                        <NA>                      <NA>        <NA>   1
#
#              FIRST        LAST  salgstid  price_pr_sqm  price_pr_bedroom  \
# 61260   2024-08-18  2025-06-14       300  26741.071429      9.983333e+05
# 104443  2025-01-26  2025-01-30         4  39295.774648      1.395000e+06
# 28624   2024-09-05  2024-10-03        28  26359.832636      2.100000e+06
# 27798   2024-06-16  2024-08-21        66  35390.070922      1.663333e+06
# 89440   2024-09-08  2024-09-08      <NA>  37121.212121      2.450000e+06
# 67162   2024-08-13  2024-09-22        40  38894.736842      2.463333e+06
# 54364   2024-08-07  2024-10-31        85  63222.222222      1.896667e+06
# 66572   2024-08-07  2024-11-07        92  22673.267327      2.290000e+06
# 134551  2024-08-18  2024-08-18      <NA>  52485.875706      3.096667e+06
# 43993   2025-05-05  2025-05-14         9  59595.959596      1.966667e+06
#
#         sqm_pr_bedroom                 clean_date postal_code  municipality  \
# 61260        37.333333 2025-06-18 22:31:20.798781        3258        LARVIK
# 104443       35.500000 2025-06-18 22:31:20.798781        3186        HORTEN
# 28624        79.666667 2025-06-18 22:31:20.798781        1348         BÆRUM
# 27798        47.000000 2025-06-18 22:31:20.798781        3475         ASKER
# 89440        66.000000 2025-06-18 22:31:20.798781        3211    SANDEFJORD
# 67162        63.333333 2025-06-18 22:31:20.798781        5239        BERGEN
# 54364        30.000000 2025-06-18 22:31:20.798781        7041     TRONDHEIM
# 66572       101.000000 2025-06-18 22:31:20.798781        6509  KRISTIANSUND
# 134551       59.000000 2025-06-18 22:31:20.798781        0681          OSLO
# 43993        33.000000 2025-06-18 22:31:20.798781        0195          OSLO
#
#                  county      region fixer-upper
# 61260          Vestfold   Østlandet       False
# 104443         Vestfold   Østlandet       False
# 28624          Akershus   Østlandet       False
# 27798          Akershus   Østlandet       False
# 89440          Vestfold   Østlandet       False
# 67162          Vestland  Vestlandet       False
# 54364         Trøndelag  Midt-Norge       False
# 66572   Møre og Romsdal  Vestlandet       False
# 134551             Oslo   Østlandet       False
# 43993              Oslo   Østlandet       False

# %%
4930340.0 - 4790000
# Out:
# 140340.0

# %%
df.sort_values(by='total_price', ascending=False)['item_id'].head(15)
# Out:
#                                 dealer                      district  \
# 133441                         private                          <NA>
# 57115                          private                          <NA>
# 87901                       ASK Møller                          <NA>
# 145974                      ASK Møller                          <NA>
# 106351                      ASK Møller                          <NA>
# 102883                      ASK Møller                          <NA>
# 60715                          private                          <NA>
# 146582                         private                          <NA>
# 105622                         private                          <NA>
# 51810          TINHOLT Eiendomsmegling                          <NA>
# 148739         TINHOLT Eiendomsmegling                        skøyen
# 17354                 Fjord & Partners                       frogner
# 111895  PrivatMegleren Dyve & Partnere  Sjelden mulighet på Briskeby
# 67127                  Nordvik Frogner                       Frogner
# 149941                         private                          <NA>
#
#                                                   address     price  \
# 133441              Prestegårdsveien 32 og 34, 3530 Røyse   7950000
# 57115   Nils Jønsbergs vei/Slettmo boligfelt, 9130 Han...   5990000
# 87901                                       1622 Gressvik   5695000
# 145974                                      1622 Gressvik   5695000
# 106351                                      1622 Gressvik   5695000
# 102883                                      1622 Gressvik   5695000
# 60715                                Skrylen, 4513 Mandal   4670000
# 146582                     Høygilts moner, 4760 Birkeland   3990000
# 105622                       Gjøvikvegen 75, 2834 Raufoss   3190000
# 51810                          Hoffsveien 49 B, 0377 Oslo  28375000
# 148739                         Hoffsveien 49 B, 0377 Oslo  28075000
# 17354                         Drammensveien 72, 0271 Oslo  29950000
# 111895                   Eilert Sundts gate 23, 0259 Oslo  29900000
# 67127                   Thomas Heftyes gate 52, 0267 Oslo  29950000
# 149941                  Lille Øverberg vei 6, 1397 Nesøya  29950000
#
#          total_price    fees  joint_debt  monthly_common_cost  \
# 133441  7.993721e+13    <NA>        <NA>                  NaN
# 57115   6.014501e+13    <NA>        <NA>                  NaN
# 87901   5.737501e+13    <NA>        <NA>                  NaN
# 145974  5.737501e+13    <NA>        <NA>                  NaN
# 106351  5.737501e+13    <NA>        <NA>                  NaN
# 102883  5.737501e+13    <NA>        <NA>                  NaN
# 60715   4.688500e+13    <NA>        <NA>                  NaN
# 146582  4.001620e+13    <NA>        <NA>                  NaN
# 105622  3.199900e+13    <NA>        <NA>                  NaN
# 51810   3.266539e+07  165387     4125000          24773.00000
# 148739  3.236539e+07  165387     4125000              0.24773
# 17354   3.111324e+07  760060      403183              0.71860
# 111895  3.101678e+07  767210      349565           9400.00000
# 67127   3.097132e+07  766754      254568           8901.00000
# 149941  3.071925e+07  769250        <NA>                  NaN
#
#         collective_assets  tax_value property_type ownership_type  bedrooms  \
# 133441               <NA>       <NA>      Enebolig          Eier          4
# 57115                <NA>       <NA>      Enebolig          Eier          3
# 87901                <NA>       <NA>         Andre          Eier          3
# 145974               <NA>       <NA>         Andre          Eier          3
# 106351               <NA>       <NA>         Andre          Eier          3
# 102883               <NA>       <NA>         Andre          Eier          3
# 60715                <NA>       <NA>      Enebolig          Eier          3
# 146582               <NA>       <NA>      Enebolig          Eier          3
# 105622               <NA>       <NA>  Tomannsbolig          Eier          3
# 51810                <NA>       <NA>     Leilighet          Andel         3
# 148739               <NA>       <NA>     Leilighet          Andel         3
# 17354                <NA>    5337248     Leilighet          Eier          3
# 111895               <NA>    8903934     Leilighet          Eier          4
# 67127               36867    4540421     Leilighet          Eier          3
# 149941               <NA>    4065503      Enebolig          Eier          4
#
#         internal_area  usable_area  external_area  floor  balcony  build_year  \
# 133441            150          188             38      0       45        <NA>
# 57115              96          101              5      0     <NA>        <NA>
# 87901              75           75           <NA>      0     <NA>        <NA>
# 145974             75           75           <NA>      0     <NA>        <NA>
# 106351             75           75           <NA>      0     <NA>        <NA>
# 102883             75           75           <NA>      0     <NA>        <NA>
# 60715             120          156           <NA>      0     <NA>        <NA>
# 146582            112          133             21      0       23        <NA>
# 105622             89           89           <NA>      0     <NA>        <NA>
# 51810             175          175           <NA>      5      112        2023
# 148739            175          175           <NA>      5      112        2023
# 17354             202          210              8      4        5        1900
# 111895            258          299             41      1        5        1895
# 67127             168          200             32      3        2        1918
# 149941            361          476             28      0       88        1974
#
#          energy_rating  rooms  plot_size         last_updated      item_id  \
# 133441            <NA>   <NA>       <NA>  2024-09-19 14:07:00    356041055
# 57115             <NA>   <NA>       <NA>  2024-08-16 07:13:00    339544094
# 87901             <NA>   <NA>       <NA>  2024-02-08 08:48:00  334657338.0
# 145974            <NA>   <NA>       <NA>  2024-02-08 08:48:00  334919450.0
# 106351            <NA>   <NA>       <NA>  2024-02-08 08:48:00    334657338
# 102883            <NA>   <NA>       <NA>  2024-02-08 08:48:00    334919450
# 60715             <NA>   <NA>       <NA>  2024-02-08 08:13:00    215993039
# 146582            <NA>   <NA>       <NA>  2024-10-04 14:20:00    355045870
# 105622            <NA>   <NA>       <NA>  2024-08-30 12:01:00    368365387
# 51810   B - Mørkegrønn      4       5922  2024-06-20 20:05:00  358049384.0
# 148739  B - Mørkegrønn      4       5922  24. sep. 2024 19:57    358049384
# 17354          G - Rød      5        815  25. nov. 2024 05:00    366116634
# 111895     G - Oransje      6        819  09. juni 2025 02:09    407861038
# 67127   G - Mørkegrønn      4       1053   30. mai 2025 05:37    355926092
# 149941         G - Rød   <NA>       2141  2024-08-14 00:03:00    349326503
#
#                                                     title   sold  \
# 133441                          prestegårdsveien 32 og 34  False
# 57115                            remo nord og sør slettmo  False
# 87901                                               False  False
# 145974                                              False  False
# 106351                                              False  False
# 102883                                              False  False
# 60715                                         molkebakken  False
# 146582                                     høygilts moner  False
# 105622                                     gjøvikvegen 75  False
# 51810                                               False  False
# 148739  fantastisk & sjelden toppleilighet | takterras...  False
# 17354   eksklusiv 5-roms leilighet, nyoppusset 2023/​2...  False
# 111895  Påkostet og vakker 6-roms selveier over 2 plan...  False
# 67127   Særdeles lekker Frognerleilighet med høy stand...  False
# 149941  sjelden perle! fantastisk strandeiendom med un...  False
#
#                                               description  \
# 133441  I dette flotte prosjektet er det 2 innholdsrik...
# 57115   Kort om eiendommenHer får du om en helt ny ene...
# 87901                                                <NA>
# 145974                                               <NA>
# 106351                                               <NA>
# 102883                                               <NA>
# 60715   I Molkebakken vokser det frem et nytt boligfel...
# 146582  Her kan du kjøpe frittliggende, moderne enebol...
# 105622  SALGSSTART! Nordvik Eiendomsmegling har gleden...
# 51810                                                <NA>
# 148739  Driftskostnader (kr 6.038,-) og kapitalkostnad...
# 17354   Trappevask, vaktmestertjenester, forretningsfø...
# 111895  ['Renter og avdrag, kommunale avgifter, felles...
# 67127   ['BRA-i:', '3. etasje: 168  kvm Entré, gang, k...
# 149941  29 950 000,- (Prisantydning)Omkostninger500,- ...
#
#                               email  \
# 133441                         <NA>
# 57115                          <NA>
# 87901                          <NA>
# 145974                         <NA>
# 106351                         <NA>
# 102883                         <NA>
# 60715                          <NA>
# 146582                         <NA>
# 105622                         <NA>
# 51810                          <NA>
# 148739             terje@tinholt.no
# 17354                hh@partners.no
# 111895  lars.ryen@privatmegleren.no
# 67127   f.horntvedt@nordvikbolig.no
# 149941                         <NA>
#
#                                        contact_person        phone  \
# 133441                                       ('', '')         <NA>
# 57115                                        ('', '')         <NA>
# 87901   ('Dag Thomas Svendsen', 'Karl Robert Hansen')         <NA>
# 145974  ('Dag Thomas Svendsen', 'Karl Robert Hansen')         <NA>
# 106351  ('Dag Thomas Svendsen', 'Karl Robert Hansen')         <NA>
# 102883  ('Dag Thomas Svendsen', 'Karl Robert Hansen')         <NA>
# 60715                                        ('', '')         <NA>
# 146582                                       ('', '')         <NA>
# 105622                                       ('', '')         <NA>
# 51810                 ('Terje Tinholt', 'Sara Trier')         <NA>
# 148739                                  Terje Tinholt  97 60 08 00
# 17354                                   Hans Houeland  95 97 97 96
# 111895                                      Lars Ryen  47 70 80 08
# 67127                             Frederick Horntvedt  93 42 85 50
# 149941                                       ('', '')         <NA>
#
#                                                       url  \
# 133441  https://www.finn.no/realestate/project/ad.html...
# 57115   https://www.finn.no/realestate/project/ad.html...
# 87901   https://www.finn.no/realestate/project/ad.html...
# 145974  https://www.finn.no/realestate/project/ad.html...
# 106351  https://www.finn.no/realestate/project/ad.html...
# 102883  https://www.finn.no/realestate/project/ad.html...
# 60715   https://www.finn.no/realestate/project/ad.html...
# 146582  https://www.finn.no/realestate/project/ad.html...
# 105622  https://www.finn.no/realestate/project/ad.html...
# 51810   https://www.finn.no/realestate/homes/ad.html?f...
# 148739  https://www.finn.no/realestate/homes/ad.html?f...
# 17354   https://www.finn.no/realestate/homes/ad.html?f...
# 111895  https://www.finn.no/realestate/homes/ad.html?f...
# 67127   https://www.finn.no/realestate/homes/ad.html?f...
# 149941  https://www.finn.no/realestate/homes/ad.html?f...
#
#                      scrape_date country                            web  \
# 133441 2024-10-06 00:00:00+00:00      NO                           <NA>
# 57115  2024-10-06 00:00:00+00:00      NO                           <NA>
# 87901  2024-07-01 00:00:00+00:00      NO                           <NA>
# 145974 2024-07-01 00:00:00+00:00      NO                           <NA>
# 106351 2024-06-28 00:00:00+00:00      NO                           <NA>
# 102883 2024-06-28 00:00:00+00:00      NO                           <NA>
# 60715  2024-09-05 00:00:00+00:00      NO                           <NA>
# 146582 2024-10-06 00:00:00+00:00      NO                           <NA>
# 105622 2024-10-06 00:00:00+00:00      NO                           <NA>
# 51810  2024-07-01 00:00:00+00:00      NO                           <NA>
# 148739 2024-12-18 00:00:00+00:00      NO                           <NA>
# 17354  2025-01-07 00:00:00+00:00      NO                           <NA>
# 111895 2025-06-11 00:00:00+00:00      NO  http://privatmegleren.no/dyve
# 67127  2025-06-14 00:00:00+00:00      NO                           <NA>
# 149941 2024-09-22 00:00:00+00:00      NO                           <NA>
#
#           new                                         facilities  \
# 133441   <NA>                                               <NA>
# 57115    <NA>                                               <NA>
# 87901    <NA>                                               <NA>
# 145974   <NA>                                               <NA>
# 106351   <NA>                                               <NA>
# 102883   <NA>                                               <NA>
# 60715    <NA>                                               <NA>
# 146582   <NA>                                               <NA>
# 105622   <NA>                                               <NA>
# 51810    <NA>                                               <NA>
# 148739   <NA>                                               <NA>
# 17354    <NA>                                               <NA>
# 111895  False  ['Balkong/Terrasse', 'Peis/Ildsted', 'Parkett'...
# 67127   False  ['Balkong/Terrasse', 'Barnevennlig', 'Bredbånd...
# 149941   <NA>                                               <NA>
#
#                    cadastral_num                  unit_num  \
# 133441                      <NA>                      <NA>
# 57115                       <NA>                      <NA>
# 87901                       <NA>                      <NA>
# 145974                      <NA>                      <NA>
# 106351                      <NA>                      <NA>
# 102883                      <NA>                      <NA>
# 60715                       <NA>                      <NA>
# 146582                      <NA>                      <NA>
# 105622                      <NA>                      <NA>
# 51810                       <NA>                      <NA>
# 148739                      <NA>                      <NA>
# 17354                       <NA>                      <NA>
# 111895  ['Gårdsnr', ': ', '213']  ['Bruksnr', ': ', '102']
# 67127   ['Gårdsnr', ': ', '212']  ['Bruksnr', ': ', '848']
# 149941                      <NA>                      <NA>
#
#                        section_num  rn       FIRST        LAST  salgstid  \
# 133441                        <NA>   1  2024-08-07  2024-10-06        60
# 57115                         <NA>   1  2024-08-07  2024-10-06        60
# 87901                         <NA>   1  2024-06-19  2024-07-01        12
# 145974                        <NA>   1  2024-06-19  2024-07-01        12
# 106351                        <NA>   1  2024-06-21  2024-06-28         7
# 102883                        <NA>   1  2024-06-21  2024-06-28         7
# 60715                         <NA>   1  2024-08-07  2024-09-05        29
# 146582                        <NA>   1  2024-08-07  2024-10-06        60
# 105622                        <NA>   1  2024-08-29  2024-10-06        38
# 51810                         <NA>   1  2024-06-21  2024-07-01        10
# 148739                        <NA>   1  2024-06-28  2024-12-18       173
# 17354                         <NA>   1  2024-08-21  2025-01-07       139
# 111895   ['Seksjonsnr', ': ', '2']   1  2025-05-21  2025-06-11        21
# 67127   ['Seksjonsnr', ': ', '10']   1  2024-06-16  2025-06-14       363
# 149941                        <NA>   1  2024-06-19  2024-09-22        95
#
#          price_pr_sqm  price_pr_bedroom  sqm_pr_bedroom  \
# 133441   42287.234043      1.987500e+06       47.000000
# 57115    59306.930693      1.996667e+06       33.666667
# 87901    75933.333333      1.898333e+06       25.000000
# 145974   75933.333333      1.898333e+06       25.000000
# 106351   75933.333333      1.898333e+06       25.000000
# 102883   75933.333333      1.898333e+06       25.000000
# 60715    29935.897436      1.556667e+06       52.000000
# 146582   30000.000000      1.330000e+06       44.333333
# 105622   35842.696629      1.063333e+06       29.666667
# 51810   162142.857143      9.458333e+06       58.333333
# 148739  160428.571429      9.358333e+06       58.333333
# 17354   142619.047619      9.983333e+06       70.000000
# 111895  100000.000000      7.475000e+06       74.750000
# 67127   149750.000000      9.983333e+06       66.666667
# 149941   62920.168067      7.487500e+06      119.000000
#
#                        clean_date postal_code  municipality     county  \
# 133441 2025-06-18 22:31:20.798781        3530          HOLE   Buskerud
# 57115  2025-06-18 22:31:20.798781        9130       KARLSØY      Troms
# 87901  2025-06-18 22:31:20.798781        1622   FREDRIKSTAD    Østfold
# 145974 2025-06-18 22:31:20.798781        1622   FREDRIKSTAD    Østfold
# 106351 2025-06-18 22:31:20.798781        1622   FREDRIKSTAD    Østfold
# 102883 2025-06-18 22:31:20.798781        1622   FREDRIKSTAD    Østfold
# 60715  2025-06-18 22:31:20.798781        4513     LINDESNES      Agder
# 146582 2025-06-18 22:31:20.798781        4760      BIRKENES      Agder
# 105622 2025-06-18 22:31:20.798781        2834  VESTRE TOTEN  Innlandet
# 51810  2025-06-18 22:31:20.798781        0377          OSLO       Oslo
# 148739 2025-06-18 22:31:20.798781        0377          OSLO       Oslo
# 17354  2025-06-18 22:31:20.798781        0271          OSLO       Oslo
# 111895 2025-06-18 22:31:20.798781        0259          OSLO       Oslo
# 67127  2025-06-18 22:31:20.798781        0267          OSLO       Oslo
# 149941 2025-06-18 22:31:20.798781        1397         ASKER   Akershus
#
#             region fixer-upper
# 133441   Østlandet       False
# 57115   Nord-Norge       False
# 87901    Østlandet       False
# 145974   Østlandet       False
# 106351   Østlandet       False
# 102883   Østlandet       False
# 60715    Sørlandet       False
# 146582   Sørlandet       False
# 105622   Østlandet       False
# 51810    Østlandet       False
# 148739   Østlandet       False
# 17354    Østlandet       False
# 111895   Østlandet       False
# 67127    Østlandet       False
# 149941   Østlandet       False

# %%
import seaborn as sns

# %%
sns.histplot(data = df, x = 'internal_area', bins=100, kde=True, alpha=0.5)
sns.histplot(data = df, x = 'usable_area', bins=100, kde=True,alpha = 0.5)
# Out:
# <Axes: xlabel='internal_area', ylabel='Count'>

# %%
df.head()
# Out:
# '303285584'

# %%
keys = [
        'oppussingsobjekt', 'oppussingsbehov', 'oppussingsklar','renoveringsobjekt','oppgraderingsobjekt',
        'renoveringsbehov', 'moderniseringsbehov','moderniseringsobjekt','oppgraderingsbehov','rehabilitering/oppussing', 'rehabilitering','oppussing'
        ]

regex = '|'.join(re.escape(key) for key in keys)
pattern = re.compile(regex, re.IGNORECASE)
test = df['description'].str.lower().str.contains(pattern, regex=True, na=False)
